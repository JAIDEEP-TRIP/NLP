# %%
corpus = "Jaideep enjoys solving complex problems using machine learning and deep learning. He spends his evenings reading research papers and building interesting projects. His friends often ask him for help understanding difficult programming concepts. Jaideep believes that consistent practice is the key to mastering any technology."

# %%
print(corpus)
# Out:
# Jaideep enjoys solving complex problems using machine learning and deep learning. He spends his evenings reading research papers and building interesting projects. His friends often ask him for help understanding difficult programming concepts. Jaideep believes that consistent practice is the key to mastering any technology.

# %%
# !pip install nltk
# Out:
# ...
#   Using cached nltk-3.9.4-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# ...
# Using cached nltk-3.9.4-py3-none-any.whl (1.6 MB)
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [nltk]━━━━━━ 1/2 [nltk]
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/jaideeptrip/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     /Users/jaideeptrip/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
##Tokenization
from nltk.tokenize import sent_tokenize

# %%
documents = sent_tokenize(corpus)
documents
# Out:
# ['Jaideep enjoys solving complex problems using machine learning and deep learning.',
#  'He spends his evenings reading research papers and building interesting projects.',
#  'His friends often ask him for help understanding difficult programming concepts.',
#  'Jaideep believes that consistent practice is the key to mastering any technology.']

# %%
type(documents)
# Out:
# list

# %%
#tokenization - sentense to words
from nltk.tokenize import word_tokenize

# %%
words = word_tokenize(corpus)
words
# Out:
# ['Jaideep',
#  'enjoys',
#  'solving',
#  'complex',
#  'problems',
#  'using',
#  'machine',
#  'learning',
#  'and',
#  'deep',
#  'learning',
#  '.',
#  'He',
#  'spends',
#  'his',
#  'evenings',
#  'reading',
#  'research',
#  'papers',
#  'and',
#  'building',
#  'interesting',
#  'projects',
#  '.',
#  'His',
#  'friends',
#  'often',
#  'ask',
#  'him',
#  'for',
#  'help',
#  'understanding',
#  'difficult',
#  'programming',
#  'concepts',
#  '.',
#  'Jaideep',
#  'believes',
#  'that',
#  'consistent',
#  'practice',
#  'is',
#  'the',
#  'key',
#  'to',
#  'mastering',
#  'any',
#  'technology',
#  '.']

# %%
for sentense in documents:
    print(word_tokenize(sentense))
# Out:
# ['Jaideep', 'enjoys', 'solving', 'complex', 'problems', 'using', 'machine', 'learning', 'and', 'deep', 'learning', '.']
# ['He', 'spends', 'his', 'evenings', 'reading', 'research', 'papers', 'and', 'building', 'interesting', 'projects', '.']
# ['His', 'friends', 'often', 'ask', 'him', 'for', 'help', 'understanding', 'difficult', 'programming', 'concepts', '.']
# ['Jaideep', 'believes', 'that', 'consistent', 'practice', 'is', 'the', 'key', 'to', 'mastering', 'any', 'technology', '.']
