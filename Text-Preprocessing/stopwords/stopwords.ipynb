# %%
speech = "My fellow citizens, I am standing here in front of you all today because I believe that we as a society have to work together if we are ever going to solve the problems that are affecting each and every one of us. Over the years, I have seen so many of our people struggle with issues that are not only difficult but are also very much avoidable. We have the resources, we have the talent, and we certainly have the will to make things better for all of us. But the question that I keep asking myself is, are we really doing enough? I think that we can do so much more if we just put our minds to it and stop making excuses for the things that we have not yet accomplished. The future of this great nation depends on the choices that you and I make today, not tomorrow, not next week, but right here and right now. So I urge each and every one of you to stand up, speak out, and take action because together there is absolutely nothing that we cannot achieve."

# %%
from nltk.stem import PorterStemmer

# %%
from nltk.corpus import stopwords

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jaideeptrip/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
stopwords.words('english')
# Out:
# ['a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  "he'd",
#  "he'll",
#  'her',
#  'here',
#  'hers',
#  'herself',
#  "he's",
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  "i'd",
#  'if',
#  "i'll",
#  "i'm",
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it'd",
#  "it'll",
#  "it's",
#  'its',
#  'itself',
#  "i've",
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she'd",
#  "she'll",
#  "she's",
#  'should',
#  'shouldn',
#  "shouldn't",
#  "should've",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  "they'd",
#  "they'll",
#  "they're",
#  "they've",
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  "we'd",
#  "we'll",
#  "we're",
#  'were',
#  'weren',
#  "weren't",
#  "we've",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  'your',
#  "you're",
#  'yours',
#  'yourself',
#  'yourselves',
#  "you've"]

# %%
stemmer = PorterStemmer()

# %%
documents = nltk.sent_tokenize(speech)
documents
# Out:
# ['My fellow citizens, I am standing here in front of you all today because I believe that we as a society have to work together if we are ever going to solve the problems that are affecting each and every one of us.',
#  'Over the years, I have seen so many of our people struggle with issues that are not only difficult but are also very much avoidable.',
#  'We have the resources, we have the talent, and we certainly have the will to make things better for all of us.',
#  'But the question that I keep asking myself is, are we really doing enough?',
#  'I think that we can do so much more if we just put our minds to it and stop making excuses for the things that we have not yet accomplished.',
#  'The future of this great nation depends on the choices that you and I make today, not tomorrow, not next week, but right here and right now.',
#  'So I urge each and every one of you to stand up, speak out, and take action because together there is absolutely nothing that we cannot achieve.']

# %%
##apply stopwords and filter and then apply stemming
for i in range (len(documents)):
    words = nltk.word_tokenize(documents[i])
    words = [stemmer.stem(word) for word in words if word not in set(stopwords.words('english'))]
    documents[i] = ' ' .join(words)

# %%
documents
# Out:
# ['my fellow citizen , i stand front today i believ societi work togeth ever go solv problem affect everi one us .',
#  'over year , i seen mani peopl struggl issu difficult also much avoid .',
#  'we resourc , talent , certainli make thing better us .',
#  'but question i keep ask , realli enough ?',
#  'i think much put mind stop make excus thing yet accomplish .',
#  'the futur great nation depend choic i make today , tomorrow , next week , right right .',
#  'so i urg everi one stand , speak , take action togeth absolut noth achiev .']

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer('english')

##apply stopwords and filter and then apply stemming with snow ball stemmer
for i in range (len(documents)):
    words = nltk.word_tokenize(documents[i])
    words = [snowball.stem(word) for word in words if word not in set(stopwords.words('english'))]
    documents[i] = ' ' .join(words)

documents
# Out:
# ['my fellow citizen , i stand front today i believ societi work togeth ever go solv problem affect everi one us .',
#  'over year , i seen mani peopl struggl issu difficult also much avoid .',
#  'we resourc , talent , certain make thing better us .',
#  'but question i keep ask , realli enough ?',
#  'i think much put mind stop make excus thing yet accomplish .',
#  'the futur great nation depend choic i make today , tomorrow , next week , right right .',
#  'so i urg everi one stand , speak , take action togeth absolut noth achiev .']

# %%
import nltk
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer
lemma = WordNetLemmatizer()


# #apply stopwords and filter and then apply stemming with snow ball stemmer
for i in range (len(documents)):
    words = nltk.word_tokenize(documents[i])
    words = [lemma.lemmatize(word) for word in words if word not in set(stopwords.words('english'))]
    documents[i] = ' ' .join(words)

documents
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jaideeptrip/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# ['My fellow citizen , I standing front today I believe society work together ever going solve problem affecting every one u .',
#  'Over year , I seen many people struggle issue difficult also much avoidable .',
#  'We resource , talent , certainly make thing better u .',
#  'But question I keep asking , really enough ?',
#  'I think much put mind stop making excuse thing yet accomplished .',
#  'The future great nation depends choice I make today , tomorrow , next week , right right .',
#  'So I urge every one stand , speak , take action together absolutely nothing achieve .']
